# %% [markdown]
# ## Import required modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read the dataset

# %%
data = pd.read_excel("C:/Users/Admin/OneDrive/Desktop/Major Project 2022/datadelhi.xlsx")

# %%
data.head()
# Out:
#         DATE     T    TM    Tm     SLP    HH   VV    V    VM    SO2     NO2  \
# 0 2016-01-01  16.9  25.1   6.6  1021.3  65.0  1.1  2.0   7.6  43.87  114.09
# 1 2016-01-02  15.5  24.1   7.7  1021.0  71.0  1.1  3.5  11.1  39.82   85.16
# 2 2016-01-03  14.9  22.8   8.0  1018.4  73.0  1.1  5.9  13.0  42.05   87.16
# 3 2016-01-04  16.5  23.2   8.0  1017.6  76.0  0.6  0.0   NaN  60.74  110.90
# 4 2016-01-05  18.6  26.5  11.0  1017.1  75.0  1.0  1.9   5.4  53.09  110.95
#
#      CO   PM2.5
# 0  4.10  404.07
# 1  2.93  297.16
# 2  3.48  385.13
# 3  5.61  441.53
# 4  5.15  337.37

# %% [markdown]
# ## Some standard measures of the dataset

# %%
data.describe()
# Out:
#                  T           TM           Tm          SLP           HH  \
# count  1439.000000  1439.000000  1439.000000  1383.000000  1439.000000
# mean     26.002780    32.596595    19.331480  1007.905495    62.555942
# std       7.337529     6.612713     7.791795     7.563099    16.328879
# min       6.900000    12.900000     0.700000   989.800000    20.000000
# 25%      19.600000    27.500000    12.000000  1001.100000    52.000000
# 50%      28.200000    34.400000    21.100000  1007.800000    64.000000
# 75%      31.800000    37.000000    26.200000  1014.800000    74.000000
# max      39.900000    45.600000    34.000000  1023.100000    99.000000
#
#                 VV            V           VM          SO2          NO2  \
# count  1439.000000  1439.000000  1427.000000  1287.000000  1288.000000
# mean      2.258582     6.575191    15.767344    22.818664    63.522407
# std       0.799405     3.683214     7.782365    18.018104    30.758733
# ...

# %%
data  = data.drop("DATE", axis =1)
data
# Out:
#          T    TM    Tm     SLP    HH   VV    V    VM    SO2     NO2    CO  \
# 0     16.9  25.1   6.6  1021.3  65.0  1.1  2.0   7.6  43.87  114.09  4.10
# 1     15.5  24.1   7.7  1021.0  71.0  1.1  3.5  11.1  39.82   85.16  2.93
# 2     14.9  22.8   8.0  1018.4  73.0  1.1  5.9  13.0  42.05   87.16  3.48
# 3     16.5  23.2   8.0  1017.6  76.0  0.6  0.0   NaN  60.74  110.90  5.61
# 4     18.6  26.5  11.0  1017.1  75.0  1.0  1.9   5.4  53.09  110.95  5.15
# ...    ...   ...   ...     ...   ...  ...  ...   ...    ...     ...   ...
# 1456   8.6  13.6   4.2  1019.6  83.0  0.6  3.3   7.6  10.31   41.60  1.34
# 1457   7.1  14.4   2.4  1020.8  92.0  0.5  2.4   5.4  12.52   17.22  1.88
# 1458   8.8  15.5   3.4  1020.4  85.0  0.6  3.3   5.4  10.19    6.81  1.96
# 1459   6.9  15.8   2.6  1020.4  99.0  0.2  5.4  11.1   9.38   57.05  1.25
# 1460   8.1  14.7   4.8  1021.0  84.0  1.0  4.8   9.4  12.17   12.80  1.31
#
#        PM2.5
# 0     404.07
# 1     297.16
# 2     385.13
# 3     441.53
# ...

# %% [markdown]
# ## Check for null values in the dataset using heatmap

# %%
sns.heatmap(data.isnull(), yticklabels =False, cbar = False, cmap = "viridis")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Remove null values

# %%
data = data.dropna()

# %% [markdown]
# ## Separate independent and dependent features

# %%
ind = data.iloc[:,:-1]
dep = data.iloc[:,-1]

# %%
data.count()
# Out:
# T        1115
# TM       1115
# Tm       1115
# SLP      1115
# HH       1115
# VV       1115
# V        1115
# VM       1115
# SO2      1115
# NO2      1115
# CO       1115
# PM2.5    1115
# dtype: int64

# %%
data
# Out:
#          T    TM    Tm     SLP    HH   VV    V    VM    SO2     NO2    CO  \
# 0     16.9  25.1   6.6  1021.3  65.0  1.1  2.0   7.6  43.87  114.09  4.10
# 1     15.5  24.1   7.7  1021.0  71.0  1.1  3.5  11.1  39.82   85.16  2.93
# 2     14.9  22.8   8.0  1018.4  73.0  1.1  5.9  13.0  42.05   87.16  3.48
# 4     18.6  26.5  11.0  1017.1  75.0  1.0  1.9   5.4  53.09  110.95  5.15
# 5     18.7  26.5  11.6  1016.6  78.0  1.0  3.5  11.1  41.03  103.66  7.68
# ...    ...   ...   ...     ...   ...  ...  ...   ...    ...     ...   ...
# 1456   8.6  13.6   4.2  1019.6  83.0  0.6  3.3   7.6  10.31   41.60  1.34
# 1457   7.1  14.4   2.4  1020.8  92.0  0.5  2.4   5.4  12.52   17.22  1.88
# 1458   8.8  15.5   3.4  1020.4  85.0  0.6  3.3   5.4  10.19    6.81  1.96
# 1459   6.9  15.8   2.6  1020.4  99.0  0.2  5.4  11.1   9.38   57.05  1.25
# 1460   8.1  14.7   4.8  1021.0  84.0  1.0  4.8   9.4  12.17   12.80  1.31
#
#        PM2.5
# 0     404.07
# 1     297.16
# 2     385.13
# 4     337.37
# ...

# %% [markdown]
# ## Correlation pair plot

# %%
sns.pairplot(data)

# %% [markdown]
# ### Correlation Matrix with Heatmap
# Correlation states how the features are related to each other or the target variable.
#
# Correlation can be positive (increase in one value of feature increases the value of the target variable) or negative (increase in one value of feature decreases the value of the target variable)
#
# Heatmap makes it easy to identify which features are most related to the target variable, we will plot heatmap of correlated features using the seaborn library.

# %%
corrmat = data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %% [markdown]
# ### Feature Importance
# You can get the feature importance of each feature of your dataset by using the feature importance property of the model.
#
# Feature importance gives you a score for each feature of your data, the higher the score more important or relevant is the feature towards your output variable.
#
# Feature importance is an inbuilt class that comes with Tree Based Regressor, we will be using Extra Tree Regressor for extracting the top 10 features for the dataset.

# %%
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
model.fit(ind,dep)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [0.07533793 0.02634772 0.21112514 0.06429884 0.37854868 0.01902008
#  0.02178646 0.04535397 0.08749127 0.07068992]

# %% [markdown]
# ### plot graph of feature importances for better visualization

# %%
feat_importances = pd.Series(model.feature_importances_, index=ind.columns)
feat_importances.nlargest(5).plot(kind='barh')
plt.show()

# %% [markdown]
# ## Train-Test Split

# %%
from sklearn.model_selection import train_test_split
ind_train, ind_test, dep_train, dep_test = train_test_split(ind, dep, test_size=0.3, random_state=0)

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor=LinearRegression()
regressor.fit(ind_train,dep_train)
# Out:
# LinearRegression()

# %%
print("Coefficient of determination R^2 on training set: {}".format(regressor.score(ind_train, dep_train)))
# Out:
# Coefficient of determination R^2 on training set: 0.6893276000926298

# %%
print("Coefficient of determination R^2  on testing set: {}".format(regressor.score(ind_test, dep_test)))
# Out:
# Coefficient of determination R^2  on testing set: 0.6287846198605898

# %%
prediction = regressor.predict(ind_test)

# %%
plt.scatter(dep_test, prediction)
m, b = np.polyfit(dep_test, prediction, 1)

#add linear regression line to scatterplot 
plt.plot(dep_test, m*dep_test+b)
plt.xlabel("Temperature") #x label
plt.ylabel("Concenration of PM2.5") #y label

# %%
results = pd.DataFrame({"predictions": list(prediction), "actual": dep_test})
results
# Out:
#      predictions  actual
# 715    65.492565   42.98
# 779    85.415565   73.45
# 453    94.720189  100.63
# 97     98.741523  106.06
# 471   101.008280   76.50
# ..           ...     ...
# 274    42.323733   31.92
# 507    66.499548   39.61
# 685    59.751311   46.96
# 176    56.060960   51.89
# 296    21.212160   41.99
#
# [227 rows x 2 columns]

# %% [markdown]
# ## Regression Evaluation Metrics
#
#
# Here are three common evaluation metrics for regression problems:
#
# **Mean Absolute Error** (MAE) is the mean of the absolute value of the errors:
#
# $$\frac 1n\sum_{i=1}^n|y_i-\hat{y}_i|$$
#
# **Mean Squared Error** (MSE) is the mean of the squared errors:
#
# $$\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2$$
#
# **Root Mean Squared Error** (RMSE) is the square root of the mean of the squared errors:
#
# $$\sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$
#
# Comparing these metrics:
#
# - **MAE** is the absolute average error.
# - **MSE** is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world.
# - **RMSE** is even more popular than MSE, because RMSE is interpretable in the "y" units.

# %%
from sklearn import metrics

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(dep_test, prediction))
print('Mean Square Error:', metrics.mean_squared_error(dep_test, prediction))
print('Root Mean Square Error:', np.sqrt(metrics.mean_squared_error(dep_test, prediction)))
# Out:
# Mean Absolute Error: 12.737250144403605
# Mean Square Error: 332.4415626413649
# Root Mean Square Error: 18.23298008119805

# %% [markdown]
# ## Ridge Regression

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

# %%
ridge=Ridge()
parameters={'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40]}
ridge_regressor=GridSearchCV(ridge,parameters,scoring='neg_mean_squared_error',cv=5)
ridge_regressor.fit(ind,dep)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.001, 0.01, 1, 5, 10,
#                                    20, 30, 35, 40]},
#              scoring='neg_mean_squared_error')

# %%
predictions_by_ridge = ridge_regressor.predict(ind_test)

# %%
results1 = pd.DataFrame({'pred':list(predictions_by_ridge),'actual':dep_test})
results1
# Out:
#           pred  actual
# 715  63.830425   42.98
# 779  82.220457   73.45
# 453  92.278451  100.63
# 97   97.453118  106.06
# 471  99.367372   76.50
# ..         ...     ...
# 274  42.559505   31.92
# 507  66.294159   39.61
# 685  59.285582   46.96
# 176  54.941364   51.89
# 296  22.403748   41.99
#
# [227 rows x 2 columns]

# %%
plt.scatter(dep_test, predictions_by_ridge)
x = dep_test
y = predictions_by_ridge
m, b = np.polyfit(x, y, 1)

#add linear regression line to scatterplot 
plt.plot(x, m*x+b)

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(dep_test, predictions_by_ridge))
print('Mean Square Error:', metrics.mean_squared_error(dep_test, predictions_by_ridge))
print('Root Mean Square Error:', np.sqrt(metrics.mean_squared_error(dep_test, predictions_by_ridge)))
# Out:
# Mean Absolute Error: 12.495680379474582
# Mean Square Error: 324.40452746808757
# Root Mean Square Error: 18.011233368875313

# %% [markdown]
# ## Lasso Regression

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV

# %%
lasso=Ridge()
parameters={'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40]}
lasso_regressor=GridSearchCV(lasso,parameters,scoring='neg_mean_squared_error',cv=5)
lasso_regressor.fit(ind,dep)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.001, 0.01, 1, 5, 10,
#                                    20, 30, 35, 40]},
#              scoring='neg_mean_squared_error')

# %%
predictions_by_lasso = lasso_regressor.predict(ind_test)

# %%
results2 = pd.DataFrame({'pred':list(predictions_by_lasso),'actual':dep_test})
results2
# Out:
#           pred  actual
# 715  63.830425   42.98
# 779  82.220457   73.45
# 453  92.278451  100.63
# 97   97.453118  106.06
# 471  99.367372   76.50
# ..         ...     ...
# 274  42.559505   31.92
# 507  66.294159   39.61
# 685  59.285582   46.96
# 176  54.941364   51.89
# 296  22.403748   41.99
#
# [227 rows x 2 columns]

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(dep_test, predictions_by_lasso))
print('Mean Square Error:', metrics.mean_squared_error(dep_test, predictions_by_lasso))
print('Root Mean Square Error:', np.sqrt(metrics.mean_squared_error(dep_test, predictions_by_lasso)))
# Out:
# Mean Absolute Error: 12.495680379474582
# Mean Square Error: 324.40452746808757
# Root Mean Square Error: 18.011233368875313

# %% [markdown]
# ## Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtree = DecisionTreeRegressor(criterion = "squared_error")

# %% [markdown]
# ### Hyperparameter Tuning

# %%
parameters = {
     "splitter"    : ["best","random"] ,
     "max_depth"        : [ 3, 4, 5, 6, 8, 10, 12, 15],
     "min_samples_leaf" : [ 1,2,3,4,5 ],
     "min_weight_fraction_leaf":[0.1,0.2,0.3,0.4],
     "max_features" : ["auto","log2","sqrt",None ],
     "max_leaf_nodes":[None,10,20,30,40,50,60,70]
    }

# %%
from sklearn.model_selection import GridSearchCV
grid_search=GridSearchCV(dtree,param_grid=parameters,scoring='neg_mean_squared_error',n_jobs=-1,cv=10,verbose=3)
grid_search.fit(ind_train, dep_train)
# Out:
# Fitting 10 folds for each of 10240 candidates, totalling 102400 fits
# GridSearchCV(cv=10, estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [3, 4, 5, 6, 8, 10, 12, 15],
#                          'max_features': ['auto', 'log2', 'sqrt', None],
#                          'max_leaf_nodes': [None, 10, 20, 30, 40, 50, 60, 70],
#                          'min_samples_leaf': [1, 2, 3, 4, 5],
#                          'min_weight_fraction_leaf': [0.1, 0.2, 0.3, 0.4],
#                          'splitter': ['best', 'random']},
#              scoring='neg_mean_squared_error', verbose=3)

# %%
predictions_by_dtr =grid_search.predict(ind_test)

# %%
results3 = pd.DataFrame({'pred':list(predictions_by_dtr),'actual':dep_test})
results3
# Out:
#            pred  actual
# 715   75.466724   42.98
# 779   75.466724   73.45
# 453  108.610000  100.63
# 97   108.610000  106.06
# 471  108.610000   76.50
# ..          ...     ...
# 274   41.042308   31.92
# 507   55.838929   39.61
# 685   75.466724   46.96
# 176   55.838929   51.89
# 296   28.858750   41.99
#
# [227 rows x 2 columns]

# %%
plt.scatter(dep_test, predictions_by_dtr)
x = dep_test
y = predictions_by_dtr
m, b = np.polyfit(x, y, 1)

#add linear regression line to scatterplot 
plt.plot(x, m*x+b)

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(dep_test, predictions_by_dtr))
print('Mean Square Error:', metrics.mean_squared_error(dep_test, predictions_by_dtr))
print('Root Mean Square Error:', np.sqrt(metrics.mean_squared_error(dep_test, predictions_by_dtr)))
# Out:
# Mean Absolute Error: 13.733849282856413
# Mean Square Error: 402.93363228794146
# Root Mean Square Error: 20.07320682621343

# %% [markdown]
# ## Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor()

# %%
regressor.fit(ind_train, dep_train)
# Out:
# RandomForestRegressor()

# %%
print("R^2 value for training data: ", regressor.score(ind_train,dep_train))
# Out:
# R^2 value for training data:  0.9703031510092592

# %%
print("R^2 value for testing data: ", regressor.score(ind_test,dep_test))
# Out:
# R^2 value for testing data:  0.8011453924317278

# %% [markdown]
# ### Hyperparameter Tuning

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
#Randomized Search CV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]
# Method of selecting samples for training each tree
# bootstrap = [True, False]

# %%
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

# %%
rf = RandomForestRegressor()
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 100, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
rf_random.fit(ind_train, dep_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   0.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   0.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   0.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   0.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=400; total time=   0.4s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.6s
# ...

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 500,
#  'min_samples_split': 5,
#  'min_samples_leaf': 1,
#  'max_features': 'auto',
#  'max_depth': 30}

# %%
rf_random.best_score_
# Out:
# -1738.121066448978

# %%
rf_random.score(ind_test,dep_test)
# Out:
# -1662.6124045988493

# %%
predictions_by_rf = rf_random.predict(ind_test)

# %%
results3 = pd.DataFrame({'pred':list(predictions_by_rf),'actual':dep_test})
results3
# Out:
#             pred  actual
# 1345   33.537847   35.12
# 1456  246.670126  183.52
# 203    55.716285   50.13
# 1214   71.682686   78.00
# 486   106.581728   89.80
# ...          ...     ...
# 403   105.043666   81.30
# 741   175.833280  166.83
# 867   101.878562  113.70
# 104   129.321450  130.82
# 126    91.164835   56.14
#
# [335 rows x 2 columns]

# %%
plt.scatter(dep_test, predictions_by_rf)
m, b = np.polyfit(dep_test, predictions_by_rf, 1)

#add linear regression line to scatterplot 
plt.plot(dep_test, m*dep_test+b)
plt.xlabel("Actual Values") #x label
plt.ylabel("Predicted Values") #y label
# Out:
# Text(0, 0.5, 'Predicted Values')

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(dep_test, predictions_by_rf))
print('Mean Square Error:', metrics.mean_squared_error(dep_test, predictions_by_rf))
print('Root Mean Square Error:', np.sqrt(metrics.mean_squared_error(dep_test, predictions_by_rf)))
# Out:
# Mean Absolute Error: 25.374087930510537
# Mean Square Error: 1662.6124045988493
# Root Mean Square Error: 40.77514444608197

# %% [markdown]
# ## XGBoost Regressor

# %%
import xgboost as xgb
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
regressor1=xgb.XGBRegressor()
regressor1.fit(ind_train,dep_train)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
print("R^2 value for training data: ", regressor1.score(ind_train,dep_train))
# Out:
# R^2 value for training data:  0.9996843672630678

# %%
print("R^2 value for testing data: ", regressor1.score(ind_test,dep_test))
# Out:
# R^2 value for testing data:  0.5720441254897519

# %%
predictions_by_xgb = regressor1.predict(ind_test)

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(dep_test, predictions_by_xgb))
print('Mean Square Error:', metrics.mean_squared_error(dep_test, predictions_by_xgb))
print('Root Mean Square Error:', np.sqrt(metrics.mean_squared_error(dep_test, predictions_by_xgb)))
# Out:
# Mean Absolute Error: 12.537822019266136
# Mean Square Error: 383.2554556611018
# Root Mean Square Error: 19.57691129011678

# %% [markdown]
# To minimize errors, and improve accuracy we perform Hyperparameter tuning.

# %% [markdown]
# ### Hyperparameter Tuning

# %%
#Randomized Search CV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Various learning rate parameters
learning_rate = ['0.05','0.1', '0.2','0.3','0.5','0.6']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
#Subssample parameter values
subsample=[0.7,0.6,0.8]
# Minimum child weight parameters
min_child_weight=[3,4,5,6,7]

# %%
regressor3 = xgb.XGBRegressor()

# %%
random_grid = {'n_estimators': n_estimators,
               'learning_rate': learning_rate,
               'max_depth': max_depth,
               'subsample': subsample,
               'min_child_weight': min_child_weight}

# %%
xg_random = RandomizedSearchCV(estimator = regressor3, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 100, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
xg_random.fit(ind_train, dep_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# C:\Users\Admin\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=6, n_estimators=1100, subsample=0.7; total time=   1.0s
# C:\Users\Admin\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [CV] END learning_rate=0.3, max_depth=10, min_child_weight=6, n_estimators=1100, subsample=0.7; total time=   1.1s
# ...

# %%
xg_random.best_params_
# Out:
# {'subsample': 0.6,
#  'n_estimators': 100,
#  'min_child_weight': 4,
#  'max_depth': 10,
#  'learning_rate': '0.05'}

# %%
xg_random.best_score_
# Out:
# -223.7093939135424

# %%
predictions_by_xgb = xg_random.predict(ind_test)

# %%
results4 = pd.DataFrame({'pred':list(predictions_by_xgb),'actual':dep_test})
results4
# Out:
#            pred  actual
# 715   63.348965   42.98
# 779   81.123238   73.45
# 453   91.853477  100.63
# 97   120.615509  106.06
# 471  129.519165   76.50
# ..          ...     ...
# 274   43.588196   31.92
# 507   63.681812   39.61
# 685   57.620163   46.96
# 176   60.492393   51.89
# 296   27.097681   41.99
#
# [227 rows x 2 columns]

# %%
plt.scatter(dep_test, predictions_by_xgb)
x = dep_test
y = predictions_by_xgb
m, b = np.polyfit(x, y, 1)

#add linear regression line to scatterplot 
plt.plot(x, m*x+b)

# %%
print('MAE:', metrics.mean_absolute_error(dep_test, predictions_by_xgb))
print('MSE:', metrics.mean_squared_error(dep_test, predictions_by_xgb))
print('RMSE:', np.sqrt(metrics.mean_squared_error(dep_test, predictions_by_xgb)))
# Out:
# MAE: 11.335586607340673
# MSE: 310.02383377216574
# RMSE: 17.60749368229805

# %% [markdown]
# ## ANN Regressor

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout

# %%
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = ind_train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()

# Fitting the ANN to the Training set
model_history=NN_model.fit(ind_train, dep_train,validation_split=0.33, batch_size = 10, epochs = 100)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 128)               1024
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 256)               65792
#
#  dense_3 (Dense)             (None, 256)               65792
#
#  dense_4 (Dense)             (None, 1)                 257
#
# ...
# Total params: 165,889
# Trainable params: 165,889
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 36/36 [==============================] - 1s 14ms/step - loss: 33.6938 - mean_absolute_error: 33.6938 - val_loss: 24.5637 - val_mean_absolute_error: 24.5637
# Epoch 2/100
# 36/36 [==============================] - 0s 6ms/step - loss: 25.5231 - mean_absolute_error: 25.5231 - val_loss: 24.3742 - val_mean_absolute_error: 24.3742
# Epoch 3/100
# ...

# %%
predictions_by_ANN = NN_model.predict(ind_test)
# Out:
# 8/8 [==============================] - 0s 3ms/step

# %%
results5 = pd.DataFrame({'pred':list(predictions_by_ANN),'actual':dep_test})
results5
# Out:
#             pred  actual
# 715  [60.019703]   42.98
# 779    [83.7124]   73.45
# 453  [102.67335]  100.63
# 97   [115.71061]  106.06
# 471  [122.03294]   76.50
# ..           ...     ...
# 274  [41.223564]   31.92
# 507  [73.769936]   39.61
# 685   [69.48444]   46.96
# 176   [55.99757]   51.89
# 296   [33.41574]   41.99
#
# [227 rows x 2 columns]

# %%
plt.scatter(dep_test, predictions_by_ANN)
x = dep_test
y = predictions_by_ANN
m, b = np.polyfit(x, y, 1)

#add linear regression line to scatterplot 
plt.plot(x, m*x+b)

# %%
print('MAE:', metrics.mean_absolute_error(dep_test, predictions_by_ANN))
print('MSE:', metrics.mean_squared_error(dep_test, predictions_by_ANN))
print('RMSE:', np.sqrt(metrics.mean_squared_error(dep_test, predictions_by_ANN)))
# Out:
# MAE: 13.237812430427986
# MSE: 366.0563828142065
# RMSE: 19.1326000014166
